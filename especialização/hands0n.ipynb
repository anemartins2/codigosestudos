# %% [markdown]
# # Hands on / Atividade Final de Experiência
# Experiência: Computação Quântica: Uma Abordagem Hands On
# Curso: Pós-graduação Lato Sensu – SENAI CIMATEC - ESPECIALIZAÇÃO EM COMUNICAÇÃO QUÂNTICA
# Docente: Dr. Luiz Gustavo Esmenard Arruda
# Dicentes: Adriane Martins Alves e Carolina ______________________

# %% [markdown]
# ## Breve descrição da atividade proposta:
# Codificação Superdensa em Computação Quântica: uma implementação computacional utilizando o simulador Aer da biblioteca Qiskit.
# Descrição detalhada da atividade em pdf anexado.

# %% [markdown]
# **Primeiro passo da atividade foi instalar e importar as funções necessárias para sua execução**

# %%
pip install qiskit

# %%
pip install qiskit-aer

# %%
#importando quskit
import qiskit
import qiskit_aer
from qiskit_aer import AerSimulator
from qiskit import __version__

# %%
#Testando funcionalidade do quskit
from qiskit import __version__
# Testar funcionalidade do Aersimulator
from qiskit_aer import AerSimulator

print(__version__)

simulator = AerSimulator()
print("Simulador criado com sucesso!")
print(f"Backend: {simulator.name}")
# Out:
# 2.1.2
# Simulador criado com sucesso!
# Backend: aer_simulator

# %% [markdown]
# Apos garantir o funcionamento das ferramentas principais necessárias importamos todas as funções bases para execução do codigo.

# %%
from qiskit import QuantumCircuit, QuantumRegister, ClassicalRegister
from qiskit_aer import AerSimulator
from qiskit.visualization import plot_histogram, array_to_latex
from qiskit.result import marginal_distribution
from qiskit.circuit.library import UGate
from numpy import pi, random

# %% [markdown]
# ## Aplicação do qiskit: Protocolo de Codificação Superdensa

# %% [markdown]
# **Primeiro passo:** Alice e Bob compartilham previamente um par de qubits em um estado de Bell;
